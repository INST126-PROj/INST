# %%
'''
DEFINING QUIZ 1
'''

def quiz1():
    #added score component for quiz grade, set to 0
    score = 0    
    #ask user for answer
    answer1=input("Which option is the answer to Question 1? ")
    #if user guesses correctly
    if answer1 == "D" or answer1 == "d":
        # add another point to their score
        score=score+1
        #tell them it's correct
        print("Correct!")
    #if user guesses wrong
    else: 
        #tell them right answer
        print("Incorrect! The correct answer is D.")
    #REPEAT PROCESS FOR OTHER QUIZ QUESTIONS   
    answer2=input("Which option is the answer to Question 2? ")
    if answer2 == "G" or answer2 == "g":
        score=score+1
        print("Correct!")
    else: 
        print("Incorrect! The correct answer is G.")

    answer3=input("Which option is the answer to Question 3? ")
    if answer3 == "J" or answer3 == "j":
        score=score+1
        print("Correct!")
    else: 
        print("Incorrect! The correct answer is J.")

    answer4=input("Which option is the answer to Question 4? ")
    if answer4 == "P" or answer4 == "p":
        score=score + 1
        print("Correct!")
    else: 
        print("Incorrect! The correct answer is P.")

    #print user score from quiz
    print("Your total score for Quiz 1 is: %d out of 4" %score)
    return

# %%
'''
DEFINING QUIZ 2
'''

def quiz2():
    #added score component for quiz grade, set to 0
    score2 = 0    
    #ask user for answer
    answer5=input("Which option is the answer to Question 1? ")
    #if user guesses correctly
    if answer5 == "C" or answer5 == "c":
        # add another point to their score
        score2=score2+1
        #tell them it's correct
        print("Correct!")
    #if user guesses wrong
    else: 
        #tell them right answer
        print("Incorrect! The correct answer is C.")
    #REPEAT PROCESS FOR OTHER QUIZ QUESTIONS   
    answer6=input("Which option is the answer to Question 2? ")
    if answer6 == "E" or answer6 == "e":
        score2=score2+1
        print("Correct!")
    else: 
        print("Incorrect! The correct answer is E.")

    answer7=input("Which option is the answer to Question 3? ")
    if answer7 == "K" or answer7 == "k":
        score2=score2+1
        print("Correct!")
    else: 
        print("Incorrect! The correct answer is K.")

    answer8=input("Which option is the answer to Question 4? ")
    if answer8 == "N" or answer8 == "n":
        score2=score2 + 1
        print("Correct!")
    else: 
        print("Incorrect! The correct answer is N.")

    #print user score from quiz
    print("Your total score for Quiz 2 is: %d out of 4" %score2)
    return

# %%
"""
FINAL CODE
"""
#have program ask user for which quiz to take
print("Hello young scholar! ")
print("There is Quiz 1 which focuses on UMD facts and Quiz 2 which focuses on essay and study tips! ")
user_input=input("Which one would you like to take?")   
    #if user chooses quiz 1    
if user_input == "Quiz 1" or user_input == "quiz 1":
    #open quiz file
    f = open("Quiz1.txt")
    #read file
    text = f.read()
    #split file 
    words = text.split("-")
    #grab quiz questions
    q1= words[0]
    # print out quiz questions
    print(q1)
    quiz1()
elif user_input == "Quiz 2" or user_input == "quiz 2":
    #open quiz file
    f2 = open("Quiz2.txt")
    #read file
    text2 = f2.read()
    #split file 
    words2 = text2.split("-")
    #grab quiz questions
    q2= words2[0]
    # print out quiz questions
    print(q2)
    quiz2()
# Out:
# Hello young scholar!
# There is Quiz 1 which focuses on UMD facts and Quiz 2 which focuses on essay and study tips!
# Which one would you like to take?quiz 1
# 1) What is The Point of Failure at UMD?
# A. The top of the UMD Chapel
# B. A borderline grade in a class
# C. A point where you instantly fail when a professor points at you
# D. A myth that if you step on a certain spot on South Campus, you won’t graduate in four years.
#
# Which option is the answer to Question 1? d
# Correct!
# Which option is the answer to Question 2? f
# Incorrect! The correct answer is G.
# Which option is the answer to Question 3? vc
# Incorrect! The correct answer is J.
# Which option is the answer to Question 4? c
# Incorrect! The correct answer is P.
# Your total score for Quiz 1 is: 1 out of 4

# %%
#have program ask user for which quiz to take
user_input=input("Hello young scholar! Which quiz would you like to take? There is Quiz 1 which focuses on UMD facts and Quiz 2 which focuses on essay and study tips! Which one would you like to take? ")
#if user chooses quiz 1
if user_input == "Quiz 1" or user_input == "quiz 1":
    #open quiz file
    f = open("Quiz1.txt")
    #read file
    text = f.read()
    #split file 
    words = text.split("-")
    #grab quiz questions
    q1= words[0]
    # print out quiz questions
    print(q1)
#added score component for quiz grade, set to 0
score = 0    
#ask user for answer
answer1=input("Which option is the answer to Question 1? ")
#if user guesses correctly
if answer1 == "D" or answer1 == "d":
    # add another point to their score
    score=score+1
    #tell them it's correct
    print("Correct!")
#if user guesses wrong
else: 
    #tell them right answer
    print("Incorrect! The correct answer is D.")
    
#REPEAT PROCESS FOR OTHER QUIZ QUESTIONS   
answer2=input("Which option is the answer to Question 2? ")
if answer2 == "G" or answer2 == "g":
    score=score+1
    print("Correct!")
else: 
    print("Incorrect! The correct answer is G.")
    
answer3=input("Which option is the answer to Question 3? ")
if answer3 == "J" or answer3 == "j":
    score=score+1
    print("Correct!")
else: 
    print("Incorrect! The correct answer is J.")

answer4=input("Which option is the answer to Question 4? ")
if answer4 == "P" or answer4 == "p":
    score=score + 1
    print("Correct!")
else: 
    print("Incorrect! The correct answer is P.")

#print user score from quiz
print("Your total score for Quiz 1 is: %d out of 4" %score)
# Out:
# Hello young scholar! Which quiz would you like to take? There is Quiz 1 which focuses on UMD facts and Quiz 2 which focuses on essay and study tips! Which one would you like to take? quiz 1
# 1) What is The Point of Failure at UMD?
# A. The top of the UMD Chapel
# B. A borderline grade in a class
# C. A point where you instantly fail when a professor points at you
# D. A myth that if you step on a certain spot on South Campus, you won’t graduate in four years.
#
# Which option is the answer to Question 1? s
# Incorrect! The correct answer is D.
# Which option is the answer to Question 2? a
# Incorrect! The correct answer is G.
# Which option is the answer to Question 3? d
# Incorrect! The correct answer is J.
# Which option is the answer to Question 4? d
# Incorrect! The correct answer is P.
# Your total score for Quiz 1 is: 0 out of 4
